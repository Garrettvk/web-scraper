# %%
from datetime import datetime
start_time = datetime.now() # time of start of program

# %%
import pandas as pd
from functions import *

# %%
pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
'''
(currently this only grabs 1 product per iteration) 
use update = True to update data in product_category_urls.csv
'''
output_df = scrape_product_links() # run 1/4 scrapers 
output_df # print dataframe
# Out:
# https://www.wonatrading.com/jewelry/stainless-steel
#                                                   Product Name  \
# 0  12pairs - 3"l Stainless Steel Metal Hoop Pin Catch Earrings
#
#               Category                            Product Image File - 1  \
# 0  DZ PACKED;EARRINGS/  images/20200710/PKE3332-@GS@3L@482542@675@05.jpg
#
#                                        Product Image File - 2  \
# 0  images/20200710/des_img/PKE3332-@GS@3L@482542@675@05@1.jpg
#
#                                                                                                                  Product Description  \
# 0  Style No : 482542 Color : Gold, Rhodium  Size : 3" L (80mm) Pin Catch 12Pairs - 3"L Stainless Steel Metal Hoop Pin Catch Earrings
#
#   Cost Price
# 0       6.75

# %%
output_df.to_csv('../csv/section_1.csv', index=False) # write data to csv
