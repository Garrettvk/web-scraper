# %%
from datetime import datetime
start_time = datetime.now() # time of start of program

# %%
import pandas as pd
from functions import *

# %%
pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
'''
(currently this only grabs 1 product per iteration) 
use update = True to update data in product_category_urls.csv
'''
output_df = scrape_product_links(2) # run 1/4 scrapers 
output_df # print dataframe
# Out:
# https://www.wonatrading.com/jewelry/cubic-zirconia 1/1
# Product: 1/100
# Product: 2/100
# Product: 3/100
#                                          Product Name              Category  \
# 0  Brass Metal Cz Embellished Butterfly Stud Earrings  JEWELRY;EARRING/STUD
# 1  Brass Metal Cz Embellished Butterfly Stud Earrings  JEWELRY;EARRING/STUD
#
#                                 Product Image File - 1 Product Image File - 2  \
# 0  images/20200724/SE7119-@GD@03X025@483307@200@01.jpg
# 1  images/20200724/SE7119-@RD@03X025@483310@200@01.jpg
#
#                                                                                                                                                                              Product Description  \
# 0     Style No : 483307 Color : Gold Theme : Bug, Butterfly  Size : 0.3" X 0.25" Post Back Brass CZ Cubic Zirconia  Lead and Nickel Compliant Brass Metal CZ Embellished Butterfly Stud Earrings
# 1  Style No : 483310 Color : Rhodium Theme : Bug, Butterfly  Size : 0.3" X 0.25" Post Back Brass CZ Cubic Zirconia  Lead and Nickel Compliant Brass Metal CZ Embellished Butterfly Stud Earrings
#
#   Cost Price  \
# 0       2.00
# 1       2.00
#
#                                                                                                                                                      url
# 0  https://www.wonatrading.com/product_info.php?products_id=483307&kind=2&cPath=172_21_56&description=Brass-Metal-CZ-Embellished-Butterfly-Stud-Earrings
# 1  https://www.wonatrading.com/product_info.php?products_id=483310&kind=2&cPath=172_21_56&description=Brass-Metal-CZ-Embellished-Butterfly-Stud-Earrings

# %%
output_df.to_csv('../csv/section_3.csv', index=False) # write data to csv
