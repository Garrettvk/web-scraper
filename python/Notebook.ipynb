# %%
import pandas as pd
from functions import *
from product_links import *
import time

# %%
pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
driver_1 = get_driver() # create driver

# %%
output_df_list = [] # list cotaining dataframes of each product

output_1 = scrape_product_links(product_links[0:1], driver_1)

output_df_list.extend(output_1) # add lists together
output_df = pd.concat(output_df_list) # combine list into 1 dataframe
output_df # print dataframe
# Out:
# https://www.wonatrading.com/jewelry/jewelry-component
#                      Product Name                    Category  \
# 0  24 Pcs - Jewelry Display Cards  JEWELRY;JEWELRY COMPONENT/
#
#                             Product Image File - 1 Product Image File - 2  \
# 0  images/20200608/J6003-@GY@2X2@481072@150@02.JPG
#
#                                                              Product Description  \
# 0  Style No : 481072 Color : Gray  Size : 2" x 2" 24 PCS - Jewelry Display Cards
#
#   Cost Price
# 0       1.50
