# %%
import pandas as pd
from functions import *

pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns and rows
pd.set_option('display.max_rows', None)

pages = get_product_links()[0:2] # first 2 pages
df = get_data(pages) # dataframe from get_data function
df
# Out:
#                                  Product Name                Category  \
# 0        Gold Dipped Metal Bar Station Anklet  JEWELRY;ANKLET/FASHION
# 1  White Gold Dipped Metal Bar Station Anklet  JEWELRY;ANKLET/FASHION
#
#                                    Product Image File - 1  \
# 0  images/20200709/AK6575-@G@025H-85_2L@482327@425@01.jpg
# 1  images/20200709/AK6575-@R@025H-85_2L@482328@425@01.jpg
#
#                                              Product Image File - 2  \
# 0  images/20200709/des_img/AK6575-@G@025H-85_2L@482327@425@01@1.jpg
# 1  images/20200709/des_img/AK6575-@R@025H-85_2L@482328@425@01@1.jpg
#
#                                                                                                                                                            Product Description  \
# 0           Style No : 482327 Color : Gold  Size : 0.25" H, 8.5" + 2" L One Side Only Gold Dipped Lead and Nickel Compliant Made In Korea Gold Dipped Metal Bar Station Anklet
# 1  Style No : 482328 Color : Rhodium  Size : 0.25" H, 8.5" + 2" L One Side Only Gold Dipped Lead and Nickel Compliant Made In Korea White Gold Dipped Metal Bar Station Anklet
#
#   Cost Price
# 0       4.25
# 1       4.25
