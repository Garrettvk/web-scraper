# %%
import pandas as pd
from functions import *
# import time

pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
driver = get_driver()

# %%
get_product_links_redo(driver) # this function returns a list of every product page
# this could be sped up by using a hard coded list and using the function to update this list periodically
# Out:
# ['https://www.wonatrading.com/jewelry/stainless-steel',
#  'https://www.wonatrading.com/jewelry/watch',
#  'https://www.wonatrading.com/jewelry/jewelry-component',
#  'https://www.wonatrading.com/jewelry/jewelry-display',
#  'https://www.wonatrading.com/jewelry/anklet',
#  'https://www.wonatrading.com/jewelry/anklet/page=2',
#  'https://www.wonatrading.com/jewelry/body-jewelry',
#  'https://www.wonatrading.com/jewelry/body-jewelry/page=2',
#  'https://www.wonatrading.com/jewelry/pendant-set',
#  'https://www.wonatrading.com/jewelry/pendant-set/page=2',
#  'https://www.wonatrading.com/jewelry/pendant-set/page=3',
#  'https://www.wonatrading.com/jewelry/mask',
#  'https://www.wonatrading.com/jewelry/mask/page=2',
#  'https://www.wonatrading.com/jewelry/mask/page=3',
#  'https://www.wonatrading.com/jewelry/mask/page=4',
#  'https://www.wonatrading.com/jewelry/brooch',
#  'https://www.wonatrading.com/jewelry/brooch/page=2',
#  'https://www.wonatrading.com/jewelry/brooch/page=3',
# ...
