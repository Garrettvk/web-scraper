# %%
import pandas as pd
from functions import *
# import time

pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

get_pages_data()
# Out:
#      Product Category  # of Pages
# 0   jewelry-component           1
# 1     jewelry-display           1
# 2     stainless-steel           1
# 3               watch           1
# 4              anklet           2
# 5        body-jewelry           2
# 6         pendant-set           3
# 7                mask           4
# 8              brooch           7
# 9                ring           9
# 10     cubic-zirconia          15
# 11           necklace          73
# 12           bracelet          85
# 13            earring         137
