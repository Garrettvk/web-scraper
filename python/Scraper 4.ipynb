# %%
from datetime import datetime

# %%
import pandas as pd
from functions import *
from product_links import *

# %%
pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
product_links = split_product_links()[3] # links from section 4
driver_4 = get_driver() # first driver object

# (currently this only grabs 1 product per iteration)
output_df_list = scrape_product_links(product_links, driver_4) # run 1/4 scrapers 

output_df = pd.concat(output_df_list) # combine list into 1 dataframe
output_df.reset_index(drop=True, inplace=True)
output_df # print dataframe

# %%
# write data to csv
output_df.to_csv('../csv/section_4.csv', index=False)
# end_time = datetime.now() # time of end of program

# %%
end_time # print end time
