# %%
from datetime import datetime
start_time = datetime.now() # time of start of program

# %%
import pandas as pd
from functions import *

# %%
pd.set_option('display.max_colwidth', None) # prints entire column width
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.max_rows', None) # show all rows

# %%
'''
(currently this only grabs 1 product per iteration) 
use update = True to update data in product_category_urls.csv
'''
output_df = scrape_product_links(1) # run 1/4 scrapers 
output_df # print dataframe
# Out:
# https://www.wonatrading.com/jewelry/mask 1/1
# Product: 1/100
# Product: 2/100
# Product: 3/100
# Product: 4/100
# Product: 5/100
# Product: 6/100
#                          Product Name       Category  \
# 0  Water Color Paw Print Fashion Mask  JEWELRY;MASK/
# 1    Buffalo Check Print Fashion Mask  JEWELRY;MASK/
# 2    Buffalo Check Print Fashion Mask  JEWELRY;MASK/
# 3    Buffalo Check Print Fashion Mask  JEWELRY;MASK/
# 4     Rope Pattern Print Fashion Mask  JEWELRY;MASK/
#
#                                                Product Image File - 1  \
# 0      images/20200807/M042-@MLT@ONESIZE-90PO-10SP@483721@300@005.jpg
# 1    images/20200807/M033-@BLACK@ONESIZE-90PO-10SP@483718@300@005.jpg
# 2      images/20200807/M033-@RED@ONESIZE-90PO-10SP@483719@300@005.jpg
# 3    images/20200807/M033-@MULTI@ONESIZE-90PO-10SP@483720@300@005.jpg
# 4  images/20200513/M015-@BLACK@ONESIZE-90PO-10SPAN@480163@375@005.jpg
#
#                                                        Product Image File - 2  \
# 0    images/20200807/des_img/M042-@MLT@ONESIZE-90PO-10SP@483721@300@005@1.jpg
# 1  images/20200807/des_img/M033-@BLACK@ONESIZE-90PO-10SP@483718@300@005@1.jpg
# 2    images/20200807/des_img/M033-@RED@ONESIZE-90PO-10SP@483719@300@005@1.jpg
# 3  images/20200807/des_img/M033-@MULTI@ONESIZE-90PO-10SP@483720@300@005@1.jpg
# 4   images/20200513/des_img/M015@BLACK@ONESIZE-90PO-10SPAN@480163@375@01-.jpg
#
#                                                                                                                                                                                                                       Product Description  \
# 0  Style No : 483721 Color : Multi Theme : Animal, Paw  Size : One Size Material : 90% Polyester / 10% Spandex Reusable and Washable Comfortable 3D Fit Fast Drying Antibacterial Effect Made In Korea Water Color Paw Print Fashion Mask
# 1                        Style No : 483718 Color : Black  Size : One Size Material : 90% Polyester / 10% Spandex Reusable and Washable Comfortable 3D Fit Fast Drying Antibacterial Effect Made In Korea Buffalo Check Print Fashion Mask
# 2                          Style No : 483719 Color : Red  Size : One Size Material : 90% Polyester / 10% Spandex Reusable and Washable Comfortable 3D Fit Fast Drying Antibacterial Effect Made In Korea Buffalo Check Print Fashion Mask
# 3                        Style No : 483720 Color : Multi  Size : One Size Material : 90% Polyester / 10% Spandex Reusable and Washable Comfortable 3D Fit Fast Drying Antibacterial Effect Made In Korea Buffalo Check Print Fashion Mask
# 4                                                        Style No : 480163 Color : Black, Red  90% Poly, 10% Span Reusable and Washable Comfortable 3D Fit Fast Drying Antibacterial Effect Made In Korea Rope Pattern Print Fashion Mask
#
#   Cost Price  \
# 0       3.00
# 1       3.00
# 2       3.00
# 3       3.00
# 4       3.00
#
#                                                                                                                                    url
# 0  https://www.wonatrading.com/product_info.php?products_id=483721&kind=2&cPath=172_185&description=Water-Color-Paw-Print-Fashion-Mask
# 1    https://www.wonatrading.com/product_info.php?products_id=483718&kind=2&cPath=172_185&description=Buffalo-Check-Print-Fashion-Mask
# 2    https://www.wonatrading.com/product_info.php?products_id=483719&kind=2&cPath=172_185&description=Buffalo-Check-Print-Fashion-Mask
# 3    https://www.wonatrading.com/product_info.php?products_id=483720&kind=2&cPath=172_185&description=Buffalo-Check-Print-Fashion-Mask
# 4     https://www.wonatrading.com/product_info.php?products_id=480163&kind=2&cPath=172_185&description=Rope-Pattern-Print-Fashion-Mask

# %%
output_df.to_csv('../csv/section_2.csv', index=False) # write data to csv
